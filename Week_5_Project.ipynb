# %%
from keras import models, layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import pandas as pd 
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("concrete_data.csv")
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
x_data = df.drop('Strength', axis=1)
print(x_data.shape)
x_data.head()
# Out:
# (1030, 8)
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
y_data = df['Strength']
y_data.shape
# Out:
# (1030,)

# %% [markdown]
# ## Part A

# %%
epochs = 50
batch_size = 1
max_iter = 50
mse_list = []

for i in range(max_iter):

    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, train_size=0.3)

    model = models.Sequential()
    model.add(layers.Dense(10, activation='relu', input_shape=(8,)))
    model.add(layers.Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')

    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
    mse_list.append(model.evaluate(x_test, y_test))
# Out:
# 0
# 309/309 [==============================] - 1s 2ms/step - loss: 177.6819
# Epoch 17/50
# 309/309 [==============================] - 1s 2ms/step - loss: 168.1207
# Epoch 18/50
# 309/309 [==============================] - 0s 2ms/step - loss: 152.2015
# Epoch 19/50
# 309/309 [==============================] - 0s 2ms/step - loss: 160.5146
# Epoch 20/50
# 309/309 [==============================] - 1s 2ms/step - loss: 155.8324
# Epoch 21/50
# 309/309 [==============================] - 0s 2ms/step - loss: 164.1313
# Epoch 22/50
# 309/309 [==============================] - 0s 2ms/step - loss: 155.8979
# Epoch 23/50
# 309/309 [==============================] - 1s 2ms/step - loss: 146.9342
# Epoch 24/50
# 309/309 [==============================] - 0s 2ms/step - loss: 154.0008
# Epoch 25/50
# 309/309 [==============================] - 1s 2ms/step - loss: 141.8176
# Epoch 26/50
# 309/309 [==============================] - 0s 2ms/step - loss: 141.9420
# Epoch 27/50
# ...

# %%
mean = np.mean(mse_list)
stdev = np.std(mse_list)
print('mean: {}, std: {}'.format(mean, stdev))
# Out:
# mean: 113.37862629248926, std: 41.759970599426055

# %% [markdown]
# ## Part B

# %%
epochs = 50
batch_size = 1
max_iter = 50
mse_list = []

scaler = StandardScaler()


for i in range(max_iter):

    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, train_size=0.3)
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)

    model = models.Sequential()
    model.add(layers.Dense(10, activation='relu', input_shape=(8,)))
    model.add(layers.Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')

    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
    mse_list.append(model.evaluate(x_test, y_test))
# Out:
# s/step - loss: 119.9901
# Epoch 16/50
# 309/309 [==============================] - 1s 2ms/step - loss: 118.5066
# Epoch 17/50
# 309/309 [==============================] - 1s 2ms/step - loss: 116.9971
# Epoch 18/50
# 309/309 [==============================] - 1s 2ms/step - loss: 115.5738
# Epoch 19/50
# 309/309 [==============================] - 1s 2ms/step - loss: 114.4632
# Epoch 20/50
# 309/309 [==============================] - 1s 2ms/step - loss: 113.1116
# Epoch 21/50
# 309/309 [==============================] - 1s 2ms/step - loss: 111.9556
# Epoch 22/50
# 309/309 [==============================] - 1s 2ms/step - loss: 111.4367
# Epoch 23/50
# 309/309 [==============================] - 1s 2ms/step - loss: 110.1636
# Epoch 24/50
# 309/309 [==============================] - 1s 2ms/step - loss: 108.9962
# Epoch 25/50
# 309/309 [==============================] - 1s 2ms/step - loss: 108.0994
# Epoch 26/50
# 309/309 [==============================] - 1s 2ms/step - loss: 107.5013
# ...

# %%
mean = np.mean(mse_list)
stdev = np.std(mse_list)
print('mean: {}, std: {}'.format(mean, stdev))
# Out:
# mean: 80.46341174703696, std: 12.672679066774977

# %% [markdown]
# Big improvement over the mean from part A, a difference of 33.

# %% [markdown]
# ## Part C

# %%
epochs = 100
batch_size = 1
max_iter = 50
mse_list = []

scaler = StandardScaler()


for i in range(max_iter):

    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, train_size=0.3)
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)

    model = models.Sequential()
    model.add(layers.Dense(10, activation='relu', input_shape=(8,)))
    model.add(layers.Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')

    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
    mse_list.append(model.evaluate(x_test, y_test))
# Out:
# =======================] - 0s 1ms/step - loss: 82.9994
# Epoch 67/100
# 309/309 [==============================] - 0s 1ms/step - loss: 82.2988
# Epoch 68/100
# 309/309 [==============================] - 0s 2ms/step - loss: 82.1711
# Epoch 69/100
# 309/309 [==============================] - 0s 1ms/step - loss: 81.6096
# Epoch 70/100
# 309/309 [==============================] - 0s 1ms/step - loss: 80.9770
# Epoch 71/100
# 309/309 [==============================] - 0s 1ms/step - loss: 80.5904
# Epoch 72/100
# 309/309 [==============================] - 0s 1ms/step - loss: 80.2859
# Epoch 73/100
# 309/309 [==============================] - 0s 1ms/step - loss: 79.5585
# Epoch 74/100
# 309/309 [==============================] - 0s 1ms/step - loss: 79.3752
# Epoch 75/100
# 309/309 [==============================] - 0s 1ms/step - loss: 79.1097
# Epoch 76/100
# 309/309 [==============================] - 0s 1ms/step - loss: 78.2559
# Epoch 77/100
# ...

# %%
mean = np.mean(mse_list)
stdev = np.std(mse_list)
print('mean: {}, std: {}'.format(mean, stdev))
# Out:
# mean: 63.254949932495194, std: 18.52078668589373

# %% [markdown]
# A difference of 17 from the mean in part B

# %% [markdown]
# ## Part D

# %%
epochs = 50
batch_size = 1
max_iter = 50
mse_list = []

scaler = StandardScaler()


for i in range(max_iter):

    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, train_size=0.3)
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)

    model = models.Sequential()
    model.add(layers.Dense(10, activation='relu', input_shape=(8,)))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')

    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
    mse_list.append(model.evaluate(x_test, y_test))
# Out:
# ======================] - 1s 3ms/step - loss: 123.9665
# Epoch 15/50
# 309/309 [==============================] - 1s 3ms/step - loss: 121.5363
# Epoch 16/50
# 309/309 [==============================] - 1s 3ms/step - loss: 120.7216
# Epoch 17/50
# 309/309 [==============================] - 1s 3ms/step - loss: 118.3877
# Epoch 18/50
# 309/309 [==============================] - 1s 3ms/step - loss: 115.4584
# Epoch 19/50
# 309/309 [==============================] - 1s 3ms/step - loss: 113.0441
# Epoch 20/50
# 309/309 [==============================] - 1s 3ms/step - loss: 111.5201
# Epoch 21/50
# 309/309 [==============================] - 1s 3ms/step - loss: 107.8889
# Epoch 22/50
# 309/309 [==============================] - 1s 3ms/step - loss: 105.2840
# Epoch 23/50
# 309/309 [==============================] - 1s 3ms/step - loss: 102.1188
# Epoch 24/50
# 309/309 [==============================] - 1s 3ms/step - loss: 98.5277
# Epoch 25/50
# ...

# %%
mean = np.mean(mse_list)
stdev = np.std(mse_list)
print('mean: {}, std: {}'.format(mean, stdev))
# Out:
# mean: 67.4152859199196, std: 16.462164703450142

# %% [markdown]
# A difference of 13 from the mean in part B
